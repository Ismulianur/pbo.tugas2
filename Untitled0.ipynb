# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismulianur/pbo.tugas2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class dog:
  def __init__(self,name,age):
    self.name = name
    self.age = age

dog1 = dog("Buddy",4)
dog2 = dog("Jemmy",3)
print({dog1.name},{dog2.age})
# Out:
# {'Buddy'} {3}
